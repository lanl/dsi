# %% [markdown]
# # DSI Diana Tutorial and getting started
#
# The goal of the Data Science Infrastructure Project ([DSI](https://github.com/lanl/dsi)) is to provide a flexible, AI-ready metadata query capability which returns data subject to strict, POSIX-enforced file security. In this tutorial, you will learn how to:
#  - initialize a DSI instance
#  - load Tier 1 metadata into DSI
#  - check the metadata loaded
#  - query the metadata
#  - load Tier 2 and Tier 3 metadata into DSI
#  - apply a complex schema
#  - use DSI Sync to index and move data and metadata
#
# This tutorial uses data from the [Cloverleaf3D](https://github.com/UK-MAC/CloverLeaf3D) Lagrangian-Eulerian hydrodynamics solver. Data is provided in dsi/examples/clover3d/. Prior to running the tutorial, follow the instructions in the [Quick Start: Installation](https://lanl.github.io/dsi/installation.html) to set up DSI.

# %%
from dsi.dsi import DSI

# %%
# Create instance of DSI
baseline = DSI()
# Out:
# Created an instance of DSI

# %% [markdown]
# # Reading Metadata into DSI
#
# For this tutorial, we will use cloverleaf 3d data available in our repository.
#
# * To pull the repository, you wil need to git clone https://github.com/lanl/dsi.git
# * To access, go to examples/clover3d
#
# The data is from [Cloverleaf3D](https://github.com/UK-MAC/CloverLeaf3D), a Lagrangian-Eulerian hydrodynamics solver.
#
# The data is an **ensemble** of 8 runs, and has 5 metadata products of interest:
#
# * genesis_datacard.xlsx - data card
# * clover.in - input deck
# * clover.out - simulation statistics
# * timestamps.txt - time when simulation was launched on slurm
# * viz files - insitu outputs in vtk format

# %%
from IPython.display import HTML

HTML("""
<video width="256" height="208" controls loop>
  <source src="clover3d/movie.mp4" type="video/mp4">
  Your browser does not support the video tag.
</video>
""")
# Out:
# <video width="256" height="208" controls loop>
#   <source src="clover3d/movie.mp4" type="video/mp4">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# To begin the ingest:

# %%
# Target backend defaults to SQLite since not defined
store = DSI("dsi-diana-tutorial.db")

# Read in Datacard (Tier 1)
store.read("clover3d/dublin_core_dc.xml", 'DublinCoreDatacard')

# Read in Tier 2 and Tier 3 metadata
# dsi.read(path, reader)
store.read("./clover3d/", 'Cloverleaf')
# Out:
# Created an instance of DSI with the Sqlite backend: dsi-diana-tutorial.db
# Loaded clover3d/dublin_core_dc.xml into the tables: dublin_core_datacard
# Loaded ./clover3d/ into the tables: input, output, simulation, viz_files

# %% [markdown]
# # Exploring the loaded metadata

# %%
# How many tables do we have
store.num_tables()
# Out:
# Database now has 5 tables

# %%
# Let's see what tables were created
store.list()
# Out:
# Table: dublin_core_datacard
#   - num of columns: 15
#   - num of rows: 1
#
# Table: input
#   - num of columns: 22
#   - num of rows: 8
#
# Table: output
#   - num of columns: 10
#   - num of rows: 720
#
# Table: simulation
#   - num of columns: 2
#   - num of rows: 8
#
# Table: viz_files
#   - num of columns: 2
#   - num of rows: 80

# %%
# Let's get more details about the data
store.summary()
# Out:
# Table: dublin_core_datacard
#
# column      | type    | unique | min  | max  | avg  | std_dev
# -------------------------------------------------------------
# Creator     | VARCHAR | 1      | None | None | None | None
# Contributor | VARCHAR | 1      | None | None | None | None
# Publisher   | VARCHAR | 1      | None | None | None | None
# Title       | VARCHAR | 1      | None | None | None | None
# Date        | VARCHAR | 1      | None | None | None | None
# Language    | VARCHAR | 1      | None | None | None | None
# Format      | VARCHAR | 1      | None | None | None | None
# Subject     | VARCHAR | 1      | None | None | None | None
# Description | VARCHAR | 1      | None | None | None | None
# Identifier  | VARCHAR | 1      | None | None | None | None
# Relation    | VARCHAR | 1      | None | None | None | None
# Source      | VARCHAR | 1      | None | None | None | None
# Type        | VARCHAR | 1      | None | None | None | None
# Coverage    | VARCHAR | 1      | None | None | None | None
# Rights      | VARCHAR | 1      | None | None | None | None
#
# Table: input
#
# column           | type    | unique | min  | max  | avg                 | std_dev
# ------------------------------------------------------------------------------------------------
# sim_id           | INTEGER | 8      | 1    | 8    | 4.5                 | 2.29128784747792
# state1_density   | FLOAT   | 1      | 0.2  | 0.2  | 0.19999999999999998 | 2.7755575615628914e-17
# state1_energy    | FLOAT   | 1      | 1.0  | 1.0  | 1.0                 | 0.0
# state2_density   | FLOAT   | 8      | 2.0  | 9.0  | 5.5                 | 2.29128784747792
# state2_energy    | FLOAT   | 1      | 2.5  | 2.5  | 2.5                 | 0.0
# state2_geometry  | VARCHAR | 1      | None | None | None                | None
# state2_xmin      | FLOAT   | 1      | 0.0  | 0.0  | 0.0                 | 0.0
# state2_xmax      | FLOAT   | 1      | 5.0  | 5.0  | 5.0                 | 0.0
# state2_ymin      | FLOAT   | 1      | 0.0  | 0.0  | 0.0                 | 0.0
# state2_ymax      | FLOAT   | 1      | 2.0  | 2.0  | 2.0                 | 0.0
# x_cells          | INTEGER | 1      | 60   | 60   | 60.0                | 0.0
# y_cells          | INTEGER | 1      | 60   | 60   | 60.0                | 0.0
# xmin             | FLOAT   | 1      | 0.0  | 0.0  | 0.0                 | 0.0
# ymin             | FLOAT   | 1      | 0.0  | 0.0  | 0.0                 | 0.0
# xmax             | FLOAT   | 1      | 10.0 | 10.0 | 10.0                | 0.0
# ymax             | FLOAT   | 1      | 10.0 | 10.0 | 10.0                | 0.0
# initial_timestep | FLOAT   | 1      | 0.04 | 0.04 | 0.04                | 0.0
# timestep_rise    | FLOAT   | 1      | 1.5  | 1.5  | 1.5                 | 0.0
# max_timestep     | FLOAT   | 1      | 0.04 | 0.04 | 0.04                | 0.0
# end_step         | INTEGER | 1      | 90   | 90   | 90.0                | 0.0
# test_problem     | INTEGER | 1      | 2    | 2    | 2.0                 | 0.0
# visit_frequency  | INTEGER | 1      | 10   | 10   | 10.0                | 0.0
#
# Table: output
#
# column                | type    | unique | min                    | max                    | avg                    | std_dev
# -------------------------------------------------------------------------------------------------------------------------------------------
# sim_id                | INTEGER | 8      | 1                      | 8                      | 4.5                    | 2.29128784747792
# step                  | INTEGER | 90     | 1                      | 90                     | 45.5                   | 25.979158313283875
# time                  | FLOAT   | 90     | 0.0                    | 3.56                   | 1.7799999999999996     | 1.0391663325313554
# control               | VARCHAR | 1      | None                   | None                   | None                   | None
# timestep              | FLOAT   | 1      | 0.04                   | 0.04                   | 0.0399999999999994     | 6.036837696399289e-16
# x                     | FLOAT   | 1      | 0.0833                 | 0.0833                 | 0.08330000000000087    | 8.743006318923108e-16
# y                     | FLOAT   | 1      | 0.0833                 | 0.0833                 | 0.08330000000000087    | 8.743006318923108e-16
# wall_clock            | FLOAT   | 711    | 0.00021386146545410156 | 0.1322460174560547     | 0.054996451073222694   | 0.03471222483372871
# average_time_per_cell | FLOAT   | 706    | 5.9405962626139325e-08 | 3.724901212586297e-07  | 3.012494375437398e-07  | 8.578276515102002e-08
# step_time_per_cell    | FLOAT   | 211    | 5.7220458984375e-08    | 3.2230880525377062e-06 | 3.3594816737109483e-07 | 8.433991864636084e-07
#
# Table: simulation
#
# column       | type    | unique | min  | max  | avg  | std_dev
# -----------------------------------------------------------------------
# sim_id       | INTEGER | 8      | 1    | 8    | 4.5  | 2.29128784747792
# sim_datetime | VARCHAR | 2      | None | None | None | None
#
# Table: viz_files
#
# column         | type    | unique | min  | max  | avg  | std_dev
# -------------------------------------------------------------------------
# sim_id         | INTEGER | 8      | 1    | 8    | 4.5  | 2.29128784747792
# image_filepath | VARCHAR | 80     | None | None | None | None

# %%
# Preview the contents of the visualization files
store.display("viz_files")
# Out:
# Table: viz_files
#
# sim_id | image_filepath
# -------------------------------------------
# 1      | run_1/clover.00000.00001.00000.vtk
# 1      | run_1/clover.00000.00001.00010.vtk
# 1      | run_1/clover.00000.00001.00020.vtk
# 1      | run_1/clover.00000.00001.00030.vtk
# 1      | run_1/clover.00000.00001.00040.vtk
# 1      | run_1/clover.00000.00001.00050.vtk
# 1      | run_1/clover.00000.00001.00060.vtk
# 1      | run_1/clover.00000.00001.00070.vtk
# 1      | run_1/clover.00000.00001.00080.vtk
# 1      | run_1/clover.00000.00001.00090.vtk
# 2      | run_2/clover.00000.00001.00000.vtk
# 2      | run_2/clover.00000.00001.00010.vtk
# 2      | run_2/clover.00000.00001.00020.vtk
# 2      | run_2/clover.00000.00001.00030.vtk
# 2      | run_2/clover.00000.00001.00040.vtk
# 2      | run_2/clover.00000.00001.00050.vtk
# 2      | run_2/clover.00000.00001.00060.vtk
# 2      | run_2/clover.00000.00001.00070.vtk
# 2      | run_2/clover.00000.00001.00080.vtk
# 2      | run_2/clover.00000.00001.00090.vtk
# 3      | run_3/clover.00000.00001.00000.vtk
# 3      | run_3/clover.00000.00001.00010.vtk
# 3      | run_3/clover.00000.00001.00020.vtk
# 3      | run_3/clover.00000.00001.00030.vtk
# 3      | run_3/clover.00000.00001.00040.vtk
#   ... showing 25 of 80 rows

# %% [markdown]
# # DSI Find to search within the metadata
#
# DSI's find capability lets you explore your data by performing queries with the following modifiers, such as >, <, >=, <=, =, ==, ~ (contains), ~~ (contains), !=, and (X, Y) for a range between values X and Y. Additionally, by adding a "True" input will return you a collection.

# %%
# Search string or value within all tables
store.find("wall_clock > 0.10")
# Out:
# Finding all rows where 'wall_clock > 0.10' in the active backend
#
# Table: output
#
# sim_id | step | time | control | timestep | x      | y      | wall_clock          | average_time_per_cell  | step_time_per_cell
# -----------------------------------------------------------------------------------------------------------------------------------
# 1      | 80   | 3.16 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10525012016296387 | 3.6545180612140234e-07 | 3.0330816904703774e-06
# 1      | 81   | 3.2  | sound   | 0.04     | 0.0833 | 0.0833 | 0.10552811622619629 | 3.618934026961464e-07  | 7.503562503390842e-08
# 1      | 82   | 3.24 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10580706596374512 | 3.584250202023886e-07  | 7.556544409857855e-08
# 1      | 83   | 3.28 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10608291625976562 | 3.5502984022679257e-07 | 7.410844167073568e-08
# 1      | 84   | 3.32 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10635900497436523 | 3.5171628629089033e-07 | 7.443957858615452e-08
# 1      | 85   | 3.36 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10663509368896484 | 3.4848069832995046e-07 | 7.503562503390842e-08
# 1      | 86   | 3.4  | sound   | 0.04     | 0.0833 | 0.0833 | 0.10691094398498535 | 3.453195865148106e-07  | 7.470448811848959e-08
# 1      | 87   | 3.44 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10718393325805664 | 3.422220091253405e-07  | 7.417466905381945e-08
# 1      | 88   | 3.48 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10745906829833984 | 3.3920160447708285e-07 | 7.470448811848959e-08
# 1      | 89   | 3.52 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10774111747741699 | 3.362706537996785e-07  | 7.66913096110026e-08
# 1      | 90   | 3.56 | sound   | 0.04     | 0.0833 | 0.0833 | 0.13019490242004395 | nan                    | nan
# 2      | 80   | 3.16 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10534191131591797 | 3.6577052540249293e-07 | 3.0422210693359374e-06
# 2      | 81   | 3.2  | sound   | 0.04     | 0.0833 | 0.0833 | 0.1056208610534668  | 3.6221145765935115e-07 | 7.549921671549479e-08
# 2      | 82   | 3.24 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10589790344238281 | 3.5873273523842416e-07 | 7.523430718315972e-08
# 2      | 83   | 3.28 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10617494583129883 | 3.55337837454146e-07   | 7.496939765082466e-08
# 2      | 84   | 3.32 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10645294189453125 | 3.520269242544023e-07  | 7.556544409857855e-08
# 2      | 85   | 3.36 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10673403739929199 | 3.488040437885359e-07  | 7.642640007866753e-08
# 2      | 86   | 3.4  | sound   | 0.04     | 0.0833 | 0.0833 | 0.10701203346252441 | 3.4564610291513055e-07 | 7.556544409857855e-08
# 2      | 87   | 3.44 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10729098320007324 | 3.425638033207958e-07  | 7.556544409857855e-08
# 2      | 88   | 3.48 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10756993293762207 | 3.3955155598996867e-07 | 7.556544409857855e-08
# 2      | 89   | 3.52 | sound   | 0.04     | 0.0833 | 0.0833 | 0.1078500747680664  | 3.3661072024989517e-07 | 7.556544409857855e-08
# 2      | 90   | 3.56 | sound   | 0.04     | 0.0833 | 0.0833 | 0.13074803352355957 | nan                    | nan
# 3      | 80   | 3.16 | sound   | 0.04     | 0.0833 | 0.0833 | 0.10527896881103516 | 3.655519750383165e-07  | 3.060566054450141e-06
# 3      | 81   | 3.2  | sound   | 0.04     | 0.0833 | 0.0833 | 0.10556888580322266 | 3.6203321606043436e-07 | 7.801585727267796e-08
# 3      | 82   | 3.24 | sound   | 0.04     | 0.0833 | 0.0833 | 0.1058499813079834  | 3.585703973847676e-07  | 7.60952631632487e-08
#   ... showing 25 of 88 rows

# %%
# Perform a find and receive a collection
find_list = store.find("state2_density==8.0", True) # Use True to return a collection
# Out:
# Finding all rows where 'state2_density==8.0' in the active backend

# %%
# Simply display what this collection (pandas dataframe) looks like
find_list
# Out:
#    sim_id  state1_density  state1_energy  state2_density  state2_energy  \
# 0       7             0.2            1.0             8.0            2.5
#
#   state2_geometry  state2_xmin  state2_xmax  state2_ymin  state2_ymax  ...  \
# 0       rectangle          0.0          5.0          0.0          2.0  ...
#
#    xmin  ymin  xmax  ymax  initial_timestep  timestep_rise  max_timestep  \
# 0   0.0   0.0  10.0  10.0              0.04            1.5          0.04
#
#    end_step  test_problem  visit_frequency
# 0        90             2               10
#
# [1 rows x 22 columns]

# %%
find_list = store.find("time>3.0", True)
# Out:
# Finding all rows where 'time>3.0' in the active backend

# %%
find_list
# Out:
#      sim_id  step  time control  timestep       x       y  wall_clock  \
# 0         1    77  3.04   sound      0.04  0.0833  0.0833    0.093779
# 1         1    78  3.08   sound      0.04  0.0833  0.0833    0.094051
# 2         1    79  3.12   sound      0.04  0.0833  0.0833    0.094324
# 3         1    80  3.16   sound      0.04  0.0833  0.0833    0.105250
# 4         1    81  3.20   sound      0.04  0.0833  0.0833    0.105528
# ..      ...   ...   ...     ...       ...     ...     ...         ...
# 107       8    86  3.40   sound      0.04  0.0833  0.0833    0.107807
# 108       8    87  3.44   sound      0.04  0.0833  0.0833    0.108086
# 109       8    88  3.48   sound      0.04  0.0833  0.0833    0.108364
# 110       8    89  3.52   sound      0.04  0.0833  0.0833    0.108643
# 111       8    90  3.56   sound      0.04  0.0833  0.0833    0.130823
#
#      average_time_per_cell  step_time_per_cell
# 0             3.383084e-07        7.417467e-08
# 1             3.349399e-07        7.390976e-08
# 2             3.316600e-07        7.417467e-08
# 3             3.654518e-07        3.033082e-06
# 4             3.618934e-07        7.503563e-08
# ..                     ...                 ...
# 107           3.482136e-07        7.530053e-08
# 108           3.451018e-07        7.556544e-08
# 109           3.420577e-07        7.523431e-08
# 110           3.390857e-07        7.556544e-08
# 111                    NaN                 NaN
#
# [112 rows x 10 columns]

# %%
find_list = store.find("time(1.0,1.1)", True)
# Out:
# Finding all rows where 'time(1.0,1.1)' in the active backend

# %%
find_list
# Out:
#     sim_id  step  time control  timestep       x       y  wall_clock  \
# 0        1    26  1.00   sound      0.04  0.0833  0.0833    0.027203
# 1        1    27  1.04   sound      0.04  0.0833  0.0833    0.027460
# 2        1    28  1.08   sound      0.04  0.0833  0.0833    0.027737
# 3        2    26  1.00   sound      0.04  0.0833  0.0833    0.027234
# 4        2    27  1.04   sound      0.04  0.0833  0.0833    0.027484
# 5        2    28  1.08   sound      0.04  0.0833  0.0833    0.027736
# 6        3    26  1.00   sound      0.04  0.0833  0.0833    0.027260
# 7        3    27  1.04   sound      0.04  0.0833  0.0833    0.027504
# 8        3    28  1.08   sound      0.04  0.0833  0.0833    0.027748
# 9        4    26  1.00   sound      0.04  0.0833  0.0833    0.027156
# 10       4    27  1.04   sound      0.04  0.0833  0.0833    0.027405
# 11       4    28  1.08   sound      0.04  0.0833  0.0833    0.027661
# 12       5    26  1.00   sound      0.04  0.0833  0.0833    0.027056
# 13       5    27  1.04   sound      0.04  0.0833  0.0833    0.027301
# 14       5    28  1.08   sound      0.04  0.0833  0.0833    0.027547
# 15       6    26  1.00   sound      0.04  0.0833  0.0833    0.027054
# 16       6    27  1.04   sound      0.04  0.0833  0.0833    0.027304
# 17       6    28  1.08   sound      0.04  0.0833  0.0833    0.027555
# 18       7    26  1.00   sound      0.04  0.0833  0.0833    0.027828
# 19       7    27  1.04   sound      0.04  0.0833  0.0833    0.028077
# 20       7    28  1.08   sound      0.04  0.0833  0.0833    0.028329
# 21       8    26  1.00   sound      0.04  0.0833  0.0833    0.027010
# 22       8    27  1.04   sound      0.04  0.0833  0.0833    0.027256
# 23       8    28  1.08   sound      0.04  0.0833  0.0833    0.027513
#
#     average_time_per_cell  step_time_per_cell
# 0            2.906312e-07        6.947252e-08
# 1            2.825113e-07        6.973743e-08
# 2            2.751677e-07        7.496940e-08
# 3            2.909624e-07        6.781684e-08
# 4            2.827566e-07        6.748570e-08
# 5            2.751582e-07        6.801552e-08
# 6            2.912400e-07        6.755193e-08
# 7            2.829626e-07        6.609493e-08
# 8            2.752765e-07        6.583002e-08
# 9            2.901269e-07        6.688966e-08
# 10           2.819447e-07        6.722079e-08
# 11           2.744155e-07        6.920762e-08
# 12           2.890596e-07        6.662475e-08
# 13           2.808752e-07        6.609493e-08
# 14           2.732849e-07        6.642607e-08
# 15           2.890367e-07        6.609493e-08
# 16           2.809047e-07        6.748570e-08
# 17           2.733630e-07        6.808175e-08
# 18           2.973075e-07        6.834666e-08
# 19           2.888593e-07        6.755193e-08
# 20           2.810430e-07        6.808175e-08
# 21           2.885680e-07        6.609493e-08
# 22           2.804116e-07        6.669097e-08
# 23           2.729467e-07        6.947252e-08

# %% [markdown]
# # Query DSI
#
# DSI Supports direct SQL queries to the metadata that you have ingested

# %%
# Use sql statement to directly query the backend store
store.query("SELECT sim_id, xmin, ymin, xmax, ymax, state2_density FROM input") # Adding 'True' gives a collection
# Out:
# Printing the result of the query: SELECT sim_id, xmin, ymin, xmax, ymax, state2_density FROM input
#
# sim_id | xmin | ymin | xmax | ymax | state2_density
# ---------------------------------------------------
# 1.0    | 0.0  | 0.0  | 10.0 | 10.0 | 2.0
# 2.0    | 0.0  | 0.0  | 10.0 | 10.0 | 3.0
# 3.0    | 0.0  | 0.0  | 10.0 | 10.0 | 4.0
# 4.0    | 0.0  | 0.0  | 10.0 | 10.0 | 5.0
# 5.0    | 0.0  | 0.0  | 10.0 | 10.0 | 6.0
# 6.0    | 0.0  | 0.0  | 10.0 | 10.0 | 7.0
# 7.0    | 0.0  | 0.0  | 10.0 | 10.0 | 8.0
# 8.0    | 0.0  | 0.0  | 10.0 | 10.0 | 9.0

# %%
store.list()
# Out:
# Table: dublin_core_datacard
#   - num of columns: 15
#   - num of rows: 1
#
# Table: input
#   - num of columns: 22
#   - num of rows: 8
#
# Table: output
#   - num of columns: 10
#   - num of rows: 720
#
# Table: simulation
#   - num of columns: 2
#   - num of rows: 8
#
# Table: viz_files
#   - num of columns: 2
#   - num of rows: 80

# %%
# alternative to "query()" if you want to get a whole table
store.get_table("genesis_datacard", True) # Adding 'True' gives a collection
# Out:
# WARNING: 'genesis_datacard' does not exist in this database

# %% [markdown]
# # DSI Write - Complex Schemas
#
# By formatting your metadata and putting it into DSI, you have essentially created a schema. DSI also has support to represent complex schemas by defining relations. For example, if you would like to relate the different tables together you can use the schema reader which takes in a .json file.
#
# * schema.json

# %% [raw]
# {
#    "genesis_datacard": {
#        "primary_key": "Title"
#    },
#     "simulation": {
#        "primary_key": "sim_id",
#        "foreign_key": {
#              "dataset": ["genesis_datacard", "Title"]
#        }
#     },
#     "input": {
#        "foreign_key": {
#              "sim_id": ["simulation", "sim_id"]
#        }
#     },
#     "output": {
#        "foreign_key": {
#              "sim_id": ["simulation", "sim_id"]
#        }
#     },
#     "viz_files": {
#        "foreign_key": {
#              "sim_id": ["simulation", "sim_id"]
#        }
#     }
# }

# %% [markdown]
# Before defining and ingesting a complex schema, what does an Entity Relationship Diagram look like in our initial schema?

# %% [markdown]
# * To run this portion of the example, the graphviz package is required

# %% [markdown]
# pip install graphviz
#
# brew install graphviz (or if admin permissions: sudo apt-get install graphviz)

# %%
from IPython.display import Image

# %%
store.write("clover_er_diagram_no_schema.png", "ER_Diagram")

Image(filename="clover_er_diagram_no_schema.png", width=200)
# Out:
# Successfully wrote to the output file clover_er_diagram_no_schema.png

# %%
# Create a new database where we will relate a complex schema
schema_store = DSI("diana_schema_tutorial.db")

# dsi.schema(filename)
schema_store.schema("./clover3d/schema2.json") # Schema neeeds to be defined before reading Cloverleaf data

# Read in Tier 2 and Tier 3 metadata
# dsi.read(path, reader)
schema_store.read("./clover3d/", 'Cloverleaf')

# Read in Datacard (Tier 1)
schema_store.read("clover3d/dublin_core_dc.xml", 'DublinCoreDatacard')

schema_store.summary()

# dsi.write(filename, writer)
schema_store.write("clover_er_diagram.png", "ER_Diagram")
# Out:
# Created an instance of DSI with the Sqlite backend: diana_schema_tutorial.db
# Successfully loaded the schema file: ./clover3d/schema2.json
# Loaded ./clover3d/ into the tables: input, output, simulation, viz_files
# Loaded clover3d/dublin_core_dc.xml into the tables: dublin_core_datacard
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[25], line 14
#      11 # Read in Datacard (Tier 1)
#      12 schema_store.read("clover3d/dublin_core_dc.xml", 'DublinCoreDatacard')
# ---> 14 schema_store.summary()
#      16 # dsi.write(filename, writer)
#      17 schema_store.write("clover_er_diagram.png", "ER_Diagram")
#
# File /Users/Shared/dev/dsi/dsi/dsi.py:1169, in DSI.summary(self, table_name, collection)
#    1153 """
#    1154 Prints numerical metadata and (optionally) sample data from tables in the active backend.
#    1155
#    (...)
#    1166     If False (default), prints each table's name and numerical metadata to the console.
#    1167 """
#    1168 if not self.t.valid_backend(self.main_backend_obj, self.main_backend_obj.__class__.__bases__[0].__name__):
# -> 1169     raise RuntimeError("ERROR: Cannot call summary() on an empty backend. Please ensure there is data in it.")
#    1170 if self.schema_read:
#    1171     raise RuntimeError("ERROR: Cannot call summary() until all associated data is loaded after a complex schema")
#
# RuntimeError: ERROR: Cannot call summary() on an empty backend. Please ensure there is data in it.

# %% [markdown]
# To preview the Entity Realationship Diagram (ERDiagram), import libraries to display images

# %%
Image(filename="clover_er_diagram.png", width=300)

# %% [markdown]
# # DSI Write - CSV
#
# DSI Support the output (write) of metadata if you would like to export into another project. For example, here we want to export the table "input" into a csv file.

# %%
store.write("input.csv", "CSV", "input")

# %% [markdown]
# # Ending your workflow

# %%
store.close()
schema_store.close()

# %% [markdown]
# # Reloading your workflow

# %%
# Target backend defaults to SQLite since not defined
store = DSI("dsi-diana-tutorial.db")
store.summary()

# %% [markdown]
# # Moving your data and metadata with DSI

# %% [markdown]
# Once metadata has been ingested, you can use DSI's copy/move capabilities to stage and target local or remote locations.
# On a DSI move, first a local data location and remote location need to be defined. DSI requires an indexing step to for internal book-keeping. DSI will not copy or move until an index is ran.

# %%
from dsi.sync import Sync

# %% [markdown]
# Both file paths should be absolute paths, ../../'s are not allowed for example

# %%
#Origin
local_files = "./clover3d/"
#Remote (Assuming on a Macbook, otherwise change to other location)
remote_path = "/Users/Shared/staging/"

# %% [markdown]
# Create a Sync object. DSI expects the 'project name' to be the name of your database file.
# Rename the database file before this step if you'd like to rename the project, before indexing.
# For example, 'dsi-tutorial.db' will be the project name for this example.

# %%
# Create Sync type with project name
s = Sync("dsi-diana-tutorial")

# %% [markdown]
# Run the index call, passing the True flag will enable debug mode that prints the progress of the index (filecrawl) and the entry into the database.

# %%
s.index(local_files,remote_path,True) # These are user defined for now

# %% [markdown]
# (Optional) Print out the status of the database. This needs to use the previous store object (not Sync object).

# %%
store.summary()

# %% [markdown]
# The user needs to invoke the DSI Copy method. By calling "copy", this will initiate a local filesystem Unix/Windows copy to move the data and metadata database to the remote location. DSI will automatically create a new folder at the remote location that is the name of the project, and then attempt to initiate a copy. True will print out the status of the move.

# %%
s.copy("copy",True)
