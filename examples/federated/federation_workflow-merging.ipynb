# %% [markdown]
# # Federation Demo
# In this demo, you will be shown:
# - how to see the datasets imported
# - how to search for data
# - merge data from different tables
# - add a table to an existing database

# %%
## Some inporte

# %%
import pandas as pd

from dsi.dsi import DSI

from dsi.dsifederated import DSIFederated

# %%
help(DSI)

# %%
help(DSIFederated)

# %% [markdown]
# ## Specify the folder where DSI Federate ran

# %%
workspace_folder = "/Users/pascalgrosset/projects/dsi/dsi_databases_00"

# %% [markdown]
# ## Access the data

# %%
federated_dbs = DSIFederated(workspace_folder, operating_mode="notebook")

# %%
federated_dbs.f_list_databases()

# %%
federated_dbs.f_merge(src_db_id='flawless-sunfish',src_tbl_name='data', dst_db_id='economic-dragon',dst_tbl_name='data')

# %%
federated_dbs.f_merge(src_db_id='ebony-crane',src_tbl_name='data', dst_db_id='economic-dragon',dst_tbl_name='data')

# %%
federated_dbs.f_add_table(src_db_id='real-malkoha',src_tbl_name='data', dst_db_id='economic-dragon', dst_tbl_name='model')
