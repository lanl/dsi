# %%
import plotly.express as px
from dsi.core import Terminal

# %%
t = Terminal()
t.load_module('backend','Sqlite','back-read', filename="wildfire.db")

# %%
dt = t.artifact_handler(interaction_type='query', query = "SELECT * FROM wfdata;") #returns pandas dataframe

# %%
dt = dt.drop(columns=['FILE'])
dt

# %%
fig = px.parallel_coordinates(dt, color="wind_speed",
                             color_continuous_scale=px.colors.sequential.Plasma,
                             color_continuous_midpoint=2)
fig.show()
