# %% [markdown]
# # DSI Data Explorer Agent
#
# The role of this agent is to allow you to interface with Data Catalogue provided through the Data Science Infrasture (DSI) project.
#
# To use this agent, you will need:
#  - Access to Chat-GPT. The LANL AI team should be able to grant you access to this. The current model in use is "chatgpt-5.1"
#
# Some capabilities available to the agent, besides the ability to search databases, are:
#  - Download datasets
#  - Email generation
#  - web search
#  - arxiv paper search
#  - wikipedia search
#
# These are all demonstrated in the notebook below.
#
# **Note:**
# - LLMs can make mistakes and can exhibit random behavior from time to time.

# %% [markdown]
# ## System setup
# Do not change!!!

# %%
from dsi_explorer_agent import DSIExplorer
from dsi_explorer_agent import check_chatgpt_api_key
from dsi_explorer_agent import get_chatgpt_api_key

# %%
# Function to display and image in Jupyter notebook
from PIL import Image
def display_image(img_path: str):
    img = Image.open(img_path)
    display(img)

# %% [markdown]
# Check for ChatGPT AI key

# %%
# will ask for a key if it cannot find one
if not check_chatgpt_api_key():
    get_chatgpt_api_key()

# %% [markdown]
# ## Load Dataset
# Please provide the agent with the location of the master dataset (containing datacards)

# %%
#dataset_path = input("Please enter the address of the dataset to explore:")  # when in production
dataset_path = "data/oceans_11/ocean_11_datasets.db"

# %%
# Initialize the code with diana master database
ai = DSIExplorer(dataset_path)
# Out:
# Dataset data/oceans_11/ocean_11_datasets.db has been loaded.
# The DSI Data Explorer agent is ready.

# %% [markdown]
# ### Query the datasets
#
# Use ```ai.ask("<query>")``` to query the dataset.
#   - e.g. ```ai.ask("Tell me about the datasets you have.")```
#
# You should be able to query each of the datasets and ask the agent to load them or load back the master diana database.

# %%
ai.ask("Tell me about the datasets you have.")
# Out:
# Here are the datasets currently described in this environment:
#
# 1. Deep Water Impact Ensemble Dataset
#    - Domain: physics
#    - Keywords: asteroid impact, meteor, in situ, visualization, simulation
#    - Summary: Simulation data for deep-ocean asteroid impacts, used in the IEEE SciVis 2018 contest to study impact dynamics in deep water.
#
# 2. Bowtie Dataset
#    - Domain: manufacturing
#    - Keywords: semiconductor, manufacturing
#    - Summary: ~3,600 inspection images of a semiconductor “Bowtie” part, labeled as accept/reject, with groupings by zoom, defect type (gouge, debris, etc.), lamination, and wafer position.
#
# 3. Higrad Firetex Wildfire Simulations
#    - Domain: physics
#    - Keywords: wildfire, simulation, higrad, firetec
#    - Summary: Coupled atmosphere–fire CFD simulations (Higrad + Firetec) in mountainous and canyon terrain, including 3D time series of many physical fields (velocity, temperature, turbulence, etc.) used to study wildfire spread and vorticity-driven lateral spread.
#
# 4. Gray-Scott reaction-diffusion dataset
#    - Domain: physics
#    - Keywords: gray-scott, PDE, simulation, complex dynamics
#    - Summary: 1,000-record HDF5 dataset from Gray–Scott reaction–diffusion simulations, illustrating rich nonlinear pattern formation.
#
# 5. The High Explosives & Affected Targets (HEAT) Dataset
#    - Domain: eulerian (shock physics)
#    - Keywords: high explosives, HEAT, AI-ready, ML, Eulerian
#    - Summary: 2D cylindrically symmetric simulations of multi-material shock propagation (expanding shock cylinders and perturbed layered interfaces), with time series of thermodynamic and kinematic fields, targeted at AI/ML emulation.
#
# 6. Heat Equations
#    - Domain: physics
#    - Keywords: heat, diffusion, simulation, partial differential equations
#    - Summary: 1,000-record HDF5 dataset of heat-diffusion simulations governed by the heat equation.
#
# 7. Monopoly Dataset
#    - Domain: manufacturing
#    - Keywords: CT, scans, monopoly hotels, steel, materials
#    - Summary: X-ray CT image data for 10 additively manufactured 316L steel specimens with engineered planar lack-of-fusion defects, each specimen with >1,000 high-quality TIFF slices.
#
# 8. 3D FLASH Computation of National Ignition Facility Shot
#    - Domain: fusion
#    - Keywords: NIF, fusion, 3D, simulation
#    - Summary: 61 HDF5 files capturing a 3D FLASH radiation-hydrodynamics simulation of a NIF cylindrical implosion (shot N210201-001), including multi-material concentrations and fields like density, pressure, and temperatures from 0–30 ns.
#    - This is the only one with an associated DSI database path available here: `nif.db`.
#
# If you tell me what you’d like to do (e.g., “load and analyze the NIF simulation data” or “I want a PDE dataset for ML experiments”), I can load the relevant dataset (where possible) and dig into its structure, statistics, or create plots.
# Query took: 10.68 seconds, total tokens used: 4595.

# %% [markdown]
# ## Diving into the Computation of National Ignition Facility Shot dataset

# %%
ai.ask("Do you have any implosion data?")

# %%
ai.ask("Tell me everything you have about that dataset")

# %%
ai.ask("Can you load that DSI database")

# %%
ai.ask("list the tables/variables")

# %%
ai.ask("show me some rows from nif_metadata")

# %%
ai.ask("Can you download the data for sim name: nifcylxyz_hdf5_plt_cnt_0018")

# %%
ai.ask("can you to visualize the data you downloaded with yt?")

# %%
display_image("nif_0018_slice_z_dens.png")

# %%
ai.ask("can you create a plot of dens_max over time")

# %%
display_image("dens_max_vs_timestep.png")

# %%
ai.ask("explain to me how you generated this plot")

# %%
ai.ask("who is the owner of this dataset?")

# %%
ai.ask("Can you email him and ask for more data. My name is Pascal and my email is pascalgrosset@lanl.gov")

# %% [markdown]
# ## General Inquiries

# %%
ai.ask("can you reload the master database now")

# %%
ai.ask("Tell me again what datasets you have?")

# %%
ai.ask("what is this Gray-Scott reaction-diffusion dataset?")

# %%
ai.ask("can you find some arxiv papers related to this")

# %%
ai.ask("Create a dashboard of the data you have")

# %%
ai.ask("i need it in the browser and static html")

# %%
ai.ask("I'm interested in asteroid impacts, is there anything related to it?")

# %%
ai.ask("do asteroids really impact earth")

# %%
ai.ask("can you search wikipedia for this impact: Chelyabinsk, Russia")
