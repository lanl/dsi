# %% [markdown]
# # DSI Data Explorer Agent
#
# The role of this agent is to allow you to interface with Data Catalogue provided through the Data Science Infrasture (DSI) project.
#
# Some capabilities available to the agent, besides the ability to search databases, are:
#  - Download datasets
#  - Email generation
#  - Web search
#  - Arxiv paper search
#  - Wikipedia search
#  - Summarize a paper
#
# These are all demonstrated in the notebook below.
#
# **Note:**
# - To use this agent, you will need access to an LLM with API key.
# - LLMs can make mistakes and can exhibit random behavior from time to time.

# %% [markdown]
# ## System setup
# Do not change!!!

# %%
from dsi_explorer_agent import DSIExplorer
from langchain_openai import ChatOpenAI
import os

# %%
# Function to display and image in Jupyter notebook
from PIL import Image
def display_image(img_path: str):
    img = Image.open(img_path)
    display(img)

# %% [markdown]
# ## Specify the LLM to use
# Use one of below or specify the model you have access to

# %%
llm_model = ChatOpenAI(
    model="gpt-5.1", 
    api_key=os.environ["OPENAI_API_KEY"],
)

# %% [markdown]
# ## Load Dataset
# Please provide the agent with the location of the master dataset (containing datacards)

# %%
# Initialize the code with master database
dataset_path = "data/oceans_11/ocean_11_datasets.db"
ai = DSIExplorer(llm=llm_model, db_index_name=dataset_path)

# %%
# initialize and then ask the ai to load the database
ai = DSIExplorer(llm=llm_model)
ai.ask("load the DSI database at data/oceans_11/ocean_11_datasets.db")
# Out:
# Creating workspace at: /home/pascalgrosset/projects/dsi/tools/ai_search/dsi_explorer_agent__2026_01_28__12_58
# No DSI database provided. Please load one
# The DSI database at `data/oceans_11/ocean_11_datasets.db` is now loaded and ready for queries and analysis.
# Query took: 4.01 seconds, total tokens used: 1430.

# %% [markdown]
# ### Query the datasets
#
# Use ```ai.ask("<query>")``` to query the dataset.
#   - e.g. ```ai.ask("Tell me about the datasets you have.")```
#
# You should be able to query each of the datasets and ask the agent to load them or load back the master diana database.

# %%
ai.ask("Tell me about the datasets you have.")
# Out:
# Here are the datasets currently registered in this DSI database (Ocean 11 “genesis_datacard” table):
#
# 1. Deep Water Impact Ensemble Dataset
#    - Domain: physics
#    - Keywords: asteroid impact, meteor, insitu, visualization, simulation
#    - Description: Simulations of asteroid impacts in deep ocean water, originally for the IEEE SciVis 2018 contest, focusing on visualizing and analyzing impact scenarios in ocean-covered regions of Earth.
#
# 2. Bowtie Dataset
#    - Domain: manufacturing
#    - Keywords: semiconductor, manufacturing
#    - Description: ~3,600 images of a semiconductor part (“Bowtie”), labeled as accept/reject with multiple rejection types (gouge, debris, etc.), different magnifications, and wafer-position metadata via Excel files.
#
# 3. Higrad Firetex Wildfire Simulations
#    - Domain: physics
#    - Keywords: wildfire, simulation, highgrad, firetec
#    - Description: 3D coupled atmosphere–fire simulations (Higrad + Firetec) on curvilinear grids, 500 time steps each, with fields like velocity, temperature, turbulence, heat transfer, oxygen, etc., used to study wildfire propagation and vorticity‑driven lateral spread.
#
# 4. Gray-Scott Reaction-Diffusion Dataset
#    - Domain: physics
#    - Keywords: gray-scott, pde, simulation, complex dynamics
#    - Description: 1000-record HDF5 dataset from a Gray–Scott reaction–diffusion PDE simulation, capturing complex spatiotemporal pattern formation.
#
# 5. The High Explosives & Affected Targets (HEAT) Dataset
#    - Domain: eulerian
#    - Keywords: High Explosives, HEAT, AI Ready, ML, Eulerean
#    - Description: 2D cylindrically symmetric multi-material shock simulations (CYL and PLI partitions) with thermodynamic and kinematic fields (pressure, density, temperature, velocity, stress, etc.) across multiple materials, designed as an AI/ML benchmark for shock propagation.
#
# 6. Heat Equations
#    - Domain: physics
#    - Keywords: head, diffusion, simulation, partial differential equations
#    - Description: 1000-record HDF5 dataset of heat-diffusion PDE simulations based on a standard heat equation model.
#
# 7. Monopoly Dataset
#    - Domain: manufacturing
#    - Keywords: computed tomography, scans, monopoly hotels, steel, materials
#    - Description: X-ray CT image dataset of 10 small L‑PBF AM 316L stainless-steel specimens (“Monopoly Hotels”) with engineered planar lack-of-fusion defects; each specimen has 1000+ high-quality TIFF slices.
#
# 8. 3D FLASH Computation of National Ignition Facility Shot
#    - Domain: fusion
#    - Keywords: NIF, fusion, 3d, simulation
#    - Description: 61 HDF5 outputs from a 3D FLASH simulation of a NIF cylindrical implosion (0–30 ns, 0.5 ns cadence) with fields including material concentrations (ablator, foam, chamber, marker), density, deposited energy, pressure, electron and ion temperatures.
#    - Associated DSI database file: `nif.db` (can be loaded for deeper analysis on this dataset).
#
# If you’d like, I can next:
# - Load the associated `nif.db` dataset, or
# - Help you pick a dataset for a specific task (e.g., computer vision, PDE modeling, ML benchmarking) and outline how to work with it.
# Query took: 16.13 seconds, total tokens used: 4907.

# %% [markdown]
# ## Diving into the Computation of National Ignition Facility Shot dataset

# %%
ai.ask("Do you have any implosion data?")
# Out:
# Yes. The registered dataset that includes implosion data is:
#
# - **3D FLASH Computation of National Ignition Facility Shot**
#   - Type: 3D radiation-hydrodynamics simulation of a cylindrical **implosion** experiment (NIF shot N210201-001)
#   - Time span: 0–30 ns, outputs every 0.5 ns (61 HDF5 files)
#   - Fields per timestep:
#     - Material concentrations: ablator (CH), chamber gas (He), marker (Al), foam (CH)
#     - State variables: density, pressure, deposited energy, electron temperature, ion temperature
#   - Geometry: 3D cubic domain, adaptive mesh refinement (cell size down to ~8 μm)
#   - Has its own DSI database: `nif.db`
#
# If you tell me what you want to do (e.g., visualize a slice, analyze pressure vs. time, prepare ML features), I can load the `nif.db` dataset next and work through that with you.
# Query took: 4.15 seconds, total tokens used: 5286.

# %%
ai.ask("Tell me everything you have about that dataset")

# %%
ai.ask("Can you load that DSI database")

# %%
ai.ask("list the tables/variables")

# %%
ai.ask("show me some rows from nif_metadata")

# %%
ai.ask("Can you download the data for sim name: nifcylxyz_hdf5_plt_cnt_0018")

# %%
ai.ask("can you to visualize the data you downloaded with yt?") #you will need to install yt in yout environment for this

# %%
display_image("nifcylxyz_hdf5_plt_cnt_0018_density_slice_z0.png")

# %%
ai.ask("can you create a plot of dens_max over time")

# %%
display_image("dens_max_vs_timestep.png")

# %%
ai.ask("explain to me how you generated this plot")

# %%
ai.ask("who is the owner of this dataset?")

# %%
ai.ask("Can you email him and ask for more data. My name is Pascal and my email is pascalgrosset@lanl.gov")

# %% [markdown]
# ## General Inquiries

# %%
ai.ask("can you reload the master database now")

# %%
ai.ask("Tell me again what datasets you have?")

# %%
ai.ask("what is this Gray-Scott reaction-diffusion dataset?")

# %%
ai.ask("can you find some arxiv papers related to this")

# %%
ai.ask("Create a dashboard of the data you have")

# %%
ai.ask("i need it in the browser and static html")

# %%
ai.ask("I'm interested in asteroid impacts, is there anything related to it?")

# %%
ai.ask("do asteroids really impact earth")

# %%
ai.ask("can you search wikipedia for this impact: Chelyabinsk, Russia")
