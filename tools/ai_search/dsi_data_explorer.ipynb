# %% [markdown]
# # DSI Data Explorer Agent
#
# The role of this agent is to allow you to interface with Data Catalogue provided through the Data Science Infrasture (DSI) project.
#
# Some capabilities available to the agent, besides the ability to search databases, are:
#  - Download datasets
#  - Email generation
#  - Web search
#  - Arxiv paper search
#  - Wikipedia search
#  - Summarize a paper
#
# These are all demonstrated in the notebook below.
#
# **Note:**
# - To use this agent, you will need access to an LLM with API key.
# - LLMs can make mistakes and can exhibit random behavior from time to time.

# %% [markdown]
# ## System setup
# Do not change!!!

# %%
from dsi_explorer_agent import DSIExplorer
from langchain_openai import ChatOpenAI
import os

# %%
# Function to display and image in Jupyter notebook
from PIL import Image
def display_image(img_path: str):
    img = Image.open(img_path)
    display(img)

# %% [markdown]
# ## Specify the LLM to use
# Use one of below or specify the model you have access to

# %%
llm_model = ChatOpenAI(
    model="gpt-5.2", 
    api_key=os.environ["OPENAI_API_KEY"],
)

# %% [markdown]
# ## Load Dataset
# Please provide the agent with the location of the master dataset (containing datacards)

# %%
# Initialize the code with master database
dataset_path = "data/oceans_11/ocean_11_datasets.db"
ai = DSIExplorer(llm=llm_model, db_index_name=dataset_path)
# Out:
# Creating workspace at: /home/pascalgrosset/projects/dsi/tools/ai_search/dsi_explorer_agent__2026_02_09__11_06

# %% [raw]
# or

# %%
# # initialize and then ask the ai to load the database
# ai = DSIExplorer(llm=llm_model)

# %%
# # ask the ai to load the database
# ai.ask("load the DSI database at data/oceans_11/ocean_11_datasets.db")

# %% [markdown]
# ### Query the datasets
#
# Use ```ai.ask("<query>")``` to query the dataset.
#   - e.g. ```ai.ask("Tell me about the datasets you have.")```
#
# You should be able to query each of the datasets and ask the agent to load them or load back the master diana database.

# %%
ai.ask("Tell me about the datasets you have.")
# Out:
# Here are the **8 datasets/resources** currently listed in the master database:
#
# 1) **Deep Water Impact Ensemble Dataset** (Theme: physics)
#    - Keywords: asteroid impact, meteor, insitu, visualization, simulation
#    - Updated: 2017-05-02
#    - Org/Contact: DOE:LANL — patchett@lanl.gov
#    - Summary: Simulations for studying asteroid impacts in deep ocean water (IEEE SciVis 2018 context).
#
# 2) **Bowtie Dataset** (Theme: manufacturing)
#    - Keywords: semiconductor, manufacturing
#    - Updated: 2025-08-21
#    - Org/Contact: DOE:LANL — ndebard@lanl.gov
#    - Summary: ~3,600 semiconductor part images (“Bowtie”), grouped accept/reject with defect-type groupings; includes spreadsheets for wafer position (round 2).
#
# 3) **Higrad Firetex Wildfire Simulations** (Theme: physics)
#    - Keywords: wildfire, simulation, highgrad, firetec
#    - Updated: 2023-03-22
#    - Org/Contact: DOE:LANL — rrl@lanl.gov
#    - Summary: Coupled HIGRAD/FireTec CFD wildfire simulations (multiple 3D time series; SciVis 2022), focused in part on vorticity-driven lateral spread.
#
# 4) **Gray-Scott reaction-diffusion dataset** (Theme: physics)
#    - Keywords: gray-scott, pde, simulation, complex dynamics
#    - Updated: 2025-10-13
#    - Org/Contact: DOE:LANL — ndebard@lanl.gov
#    - Summary: 1000 simulation records in a single HDF5 file generated from a Gray‑Scott reaction-diffusion model.
#
# 5) **The High Explosives & Affected Targets (HEAT) Dataset** (Theme: eulerian)
#    - Keywords: High Explosives, HEAT, AI Ready, ML, Eulerean
#    - Updated: 2025-10-14
#    - Org/Contact: DOE:LANL — hickmank@lanl.gov
#    - Summary: Physics-rich 2D cylindrically symmetric multi-material shock simulations (CYL + PLI partitions) intended as an AI/ML benchmark.
#
# 6) **Heat Equations** (Theme: physics)
#    - Keywords: head, diffusion, simulation, partial differential equations
#    - Updated: 2025-10-13
#    - Org/Contact: DOE:LANL — ndebard@lanl.gov
#    - Summary: 1000 simulation records in a single HDF5 file from a heat diffusion / heat equation simulation.
#
# 7) **Monopoly Dataset** (Theme: manufacturing)
#    - Keywords: computed tomography, scans, monopoly hotels, steel, materials
#    - Updated: 2025-10-07
#    - Org/Contact: DOE:LANL — ndebard@lanl.gov
#    - Summary: XCT/CT image stacks (>1000 TIFFs per specimen) for 10 316L AM specimens with engineered planar lack-of-fusion defects.
#
# 8) **3D FLASH Computation of National Ignition Facility Shot** (Theme: fusion)
#    - Keywords: NIF, fusion, 3d, simulation
#    - Updated: 2023-03-22
#    - Org/Contact: DOE:LANL — jpsauppe@lanl.gov
#    - Summary: 61 HDF5 outputs from a 3D FLASH radiation-hydrodynamics simulation of NIF shot N210201‑001 (0–30 ns).
#    - Associated DSI database path: **`nif.db`**
#
# If you tell me which one you want to explore, I can load its associated `dsi_database` (when provided) and query the actual data inside.
# Query took: 15.19 seconds, total tokens used: 5976.

# %% [markdown]
# ## Diving into the Computation of National Ignition Facility Shot dataset

# %%
ai.ask("Do you have any implosion data?")
# Out:
# Yes. I have **implosion data** in this resource:
#
# - **3D FLASH Computation of National Ignition Facility Shot** (Theme: fusion)
#   - Description: 3D FLASH radiation-hydrodynamics computation of a **cylindrical implosion experiment** at the **National Ignition Facility**, shot **N210201-001**.
#   - Contents: **61 HDF5 output files** spanning **0–30 ns** (every **0.5 ns**), with fields including material concentrations (`ablt`, `cham`, `mark`, `foam`), `dens`, `depo`, `pres`, `tele`, `tion`, on an AMR mesh.
#   - Associated database file: **`nif.db`**
#
# If you want, tell me to **load `nif.db`** and I can list tables/variables and pull out specific quantities/time steps.
# Query took: 11.52 seconds, total tokens used: 7135.

# %%
ai.ask("Tell me everything you have the 3D flash dataset")
# Out:
# Here’s everything I have recorded for the **“3D FLASH Computation of National Ignition Facility Shot”** dataset (from the master database entry):
#
# - **Title:** 3D FLASH Computation of National Ignition Facility Shot
# - **Keywords/Tag:** NIF, fusion, 3d, simulation
# - **Theme/Category/Domain:** fusion
# - **Update/Modification Date:** 2023-03-22 00:00:00
#
# - **Description:**
#   This data comes from a 3D FLASH [Fryxell et al. ApJS 131, 273 (2000); Tzeferacos et al. HEDP 17, 24-31 (2015)] computation of a cylindrical implosion experiment performed at the National Ignition Facility (shot number **N210201-001**). FLASH is an open-access radiation-hydrodynamics code being used to simulate high-energy-density systems. The dataset consists of a total of **61 HDF5 output files**, representing the state of the system at discrete points in time between **0 ns and 30 ns** (data output every **0.5 ns**). Each HDF5 file contains information for several state variables:
#   • **ablt**: concentration of the ablator material (plastic, CH)
#   • **cham**: concentration of the background chamber material (helium)
#   • **mark**: concentration of the marker material (aluminum)
#   • **foam**: concentration of the central foam (plastic, CH)
#   • **dens**: mass density \[g/cm^3\]
#   • **depo**: instantaneous energy per unit mass \[erg/g\] deposited by the laser drive
#   • **pres**: material pressure \[erg/cm^3\]
#   • **tele**: electron temperature \[K\]
#   • **tion**: ion temperature \[K\]
#   The data is given for every cell in the computational domain. The cubic domain extends over (x,y,z)=\[**-3.072 mm, 3.072 mm**\], but the cell count (and hence HDF5 file size) changes between timesteps due to adaptive mesh refinement. The minimum cell size used in the computation is **8 microns**.
#
# - **Contact point:** Joshua Paul Sauppe
# - **Email:** jpsauppe@lanl.gov
# - **Originating Organization:** DOE:LANL
#
# - **Access rights / classification:** unclassified
# - **CUI Restriction:** none
# - **CUI Banner Marking:** none
# - **CUI Designation Indicator:** none
#
# - **Associated DSI database file:** `nif.db`
#
# If you want “everything” beyond the description (e.g., what tables/fields are inside `nif.db`, counts, available variables, etc.), ask me to **load `nif.db`** and I’ll query it.
# Query took: 11.27 seconds, total tokens used: 8573.

# %%
ai.ask("Can you load that nif.db  database")
# Out:
# Loaded **`nif.db`** successfully.
#
# What it contains:
#
# - **Tables / contents**
#   - `array_and_types`: the arrays available (all `float`)
#     - `ablt`, `cham`, `dens`, `depo`, `foam`, `mark`, `pres`, `tele`, `tion`
#   - `nif_metadata`: per-timestep metadata including min/max for each array, shape, and a download link
#
# - **Timesteps available**
#   - **20 rows** in `nif_metadata` with `timestep` **0 → 19**
#
# - **Example entries (first 5)**
#   - `timestep 0` sim: `nifcylxyz_hdf5_plt_cnt_0000`, shape `(6360, 16, 16, 16)`, link: https://oceans11.lanl.gov/nif/N210201-001_3D_r2//nifcylxyz_hdf5_plt_cnt_0000.flash
#   - `timestep 1` sim: `...0001`, shape `(6872, 16, 16, 16)`
#   - `timestep 2` sim: `...0002`, shape `(8240, 16, 16, 16)`
#   - `timestep 3` sim: `...0003`, shape `(8656, 16, 16, 16)`
#   - `timestep 4` sim: `...0004`, shape `(8408, 16, 16, 16)`
#
# Tell me what you want next (e.g., min/max ranges over time for `dens` or `pres`, or I can download a specific timestep file from the `link`).
# Query took: 17.51 seconds, total tokens used: 10193.

# %%
ai.ask("list the tables/variables")
# Out:
# **Tables in `nif.db`:**
# - `array_and_types`
# - `nif_metadata`
#
# **Variables/arrays (from `array_and_types`, all type = float):**
# - `ablt`
# - `cham`
# - `dens`
# - `depo`
# - `foam`
# - `mark`
# - `pres`
# - `tele`
# - `tion`
# Query took: 7.67 seconds, total tokens used: 10730.

# %%
ai.ask("show me some rows from nif_metadata")
# Out:
# Here are **10 rows** from `nif_metadata` (the **last 10 timesteps**, ordered by `timestep` descending):
#
# | timestep | sim_name | num_arrays | shape | dens_min | dens_max | pres_min | pres_max | tele_max | tion_max | link |
# |---:|---|---:|---|---:|---:|---:|---:|---:|---:|---|
# | 19 | nifcylxyz_hdf5_plt_cnt_0019 | 9 | (9848, 16, 16, 16) | 1.664630690e-05 | 2.631119728 | 145610080.0 | 3.055611806e+12 | 1537032.875 | 3069856.5 | https://oceans11.lanl.gov/nif/N210201-001_3D_r2//nifcylxyz_hdf5_plt_cnt_0019.flash |
# | 18 | nifcylxyz_hdf5_plt_cnt_0018 | 9 | (9648, 16, 16, 16) | 1.518958288e-05 | 2.675061464 | 145588336.0 | 3.100807791e+12 | 1726465.0 | 2759336.5 | https://oceans11.lanl.gov/nif/N210201-001_3D_r2//nifcylxyz_hdf5_plt_cnt_0018.flash |
# | 17 | nifcylxyz_hdf5_plt_cnt_0017 | 9 | (9536, 16, 16, 16) | 1.319394960e-05 | 2.727978706 | 145576208.0 | 3.487227707e+12 | 1966580.625 | 2497284.0 | https://oceans11.lanl.gov/nif/N210201-001_3D_r2//nifcylxyz_hdf5_plt_cnt_0017.flash |
# | 16 | nifcylxyz_hdf5_plt_cnt_0016 | 9 | (9472, 16, 16, 16) | 1.218428679e-05 | 2.771131277 | 145207712.0 | 3.910526042e+12 | 2266939.25 | 2274744.0 | https://oceans11.lanl.gov/nif/N210201-001_3D_r2//nifcylxyz_hdf5_plt_cnt_0016.flash |
# | 15 | nifcylxyz_hdf5_plt_cnt_0015 | 9 | (9368, 16, 16, 16) | 1.162642002e-05 | 2.818115473 | 142838160.0 | 4.386020655e+12 | 2635311.0 | 2650226.25 | https://oceans11.lanl.gov/nif/N210201-001_3D_r2//nifcylxyz_hdf5_plt_cnt_0015.flash |
# | 14 | nifcylxyz_hdf5_plt_cnt_0014 | 9 | (9288, 16, 16, 16) | 1.116072144e-05 | 2.857941151 | 141873920.0 | 4.948165657e+12 | 3111478.5 | 3161372.75 | https://oceans11.lanl.gov/nif/N210201-001_3D_r2//nifcylxyz_hdf5_plt_cnt_0014.flash |
# | 13 | nifcylxyz_hdf5_plt_cnt_0013 | 9 | (9144, 16, 16, 16) | 1.079909634e-05 | 2.886322498 | 141492704.0 | 5.701571707e+12 | 3718145.75 | 3788193.0 | https://oceans11.lanl.gov/nif/N210201-001_3D_r2//nifcylxyz_hdf5_plt_cnt_0013.flash |
# | 12 | nifcylxyz_hdf5_plt_cnt_0012 | 9 | (8768, 16, 16, 16) | 1.056805831e-05 | 2.900741100 | 141430272.0 | 6.743539581e+12 | 4450382.5 | 4581270.5 | https://oceans11.lanl.gov/nif/N210201-001_3D_r2//nifcylxyz_hdf5_plt_cnt_0012.flash |
# | 11 | nifcylxyz_hdf5_plt_cnt_0011 | 9 | (8800, 16, 16, 16) | 1.036560843e-05 | 2.929096937 | 6352107.0 | 8.095050236e+12 | 5396837.0 | 5615558.5 | https://oceans11.lanl.gov/nif/N210201-001_3D_r2//nifcylxyz_hdf5_plt_cnt_0011.flash |
# | 10 | nifcylxyz_hdf5_plt_cnt_0010 | 9 | (8776, 16, 16, 16) | 1.012214125e-05 | 3.533582687 | 84374.4375 | 1.223922444e+13 | 6642939.0 | 7005904.0 | https://oceans11.lanl.gov/nif/N210201-001_3D_r2//nifcylxyz_hdf5_plt_cnt_0010.flash |
# Query took: 16.07 seconds, total tokens used: 19799.

# %%
ai.ask("Can you download the data for sim name: nifcylxyz_hdf5_plt_cnt_0018")
# Out:
# Downloaded `nifcylxyz_hdf5_plt_cnt_0018` to:
#
# `/home/pascalgrosset/projects/dsi/tools/ai_search/dsi_explorer_agent__2026_02_09__11_06/nifcylxyz_hdf5_plt_cnt_0018.flash`
# Query took: 52.52 seconds, total tokens used: 20337.

# %%
ai.ask("can you to visualize the data you downloaded with yt?") #you will need to install yt in yout environment for this
# Out:
# Python REPL can execute arbitrary code. Use with caution.
# `yt` is installed, but it **couldn’t identify the dataset type** for the downloaded file:
#
# - File: `/home/pascalgrosset/projects/dsi/tools/ai_search/dsi_explorer_agent__2026_02_09__11_06/nifcylxyz_hdf5_plt_cnt_0018.flash`
# - Error on `yt.load(...)`: **`YTUnidentifiedDataType()`**
# - Result: I couldn’t generate slice/projection plots yet.
#
# If you want, I can try one of these next (tell me which):
# 1) **Inspect the file header** (HDF5 vs non-HDF5) and determine the right reader.
# 2) Try loading explicitly with a FLASH frontend (if applicable) by checking what yt expects for FLASH outputs.
# 3) If this `.flash` is actually a container/format yt doesn’t support directly, I can attempt to **convert/extract to an HDF5/plotfile structure** that yt can read (depending on what’s inside the file).
# Query took: 21.66 seconds, total tokens used: 22887.

# %%
display_image("nifcylxyz_hdf5_plt_cnt_0018_density_slice_z0.png")

# %%
ai.ask("can you create a plot of dens_max over time")

# %%
display_image("dens_max_over_time.png")

# %%
ai.ask("explain to me how you generated this plot")

# %%
ai.ask("who is the owner of this dataset?")

# %%
ai.ask("Can you email him and ask for more data. My name is Pascal and my email is pascalgrosset@lanl.gov")

# %% [markdown]
# ## General Inquiries

# %%
ai.ask("can you reload the master database now")

# %%
ai.ask("Tell me again what datasets you have?")

# %%
ai.ask("what is this Gray-Scott reaction-diffusion dataset?")

# %%
ai.ask("can you find some arxiv papers related to this")

# %%
ai.ask("I'm interested in asteroid impacts, is there anything related to it?")

# %%
ai.ask("do asteroids really impact earth")

# %%
ai.ask("can you search wikipedia for this impact: Chelyabinsk, Russia")
